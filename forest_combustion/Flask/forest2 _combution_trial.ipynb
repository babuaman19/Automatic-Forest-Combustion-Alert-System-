# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
# Out:
# Using TensorFlow backend.
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,shear_range = 0.2,zoom_range =0.2,horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
x_train = train_datagen.flow_from_directory(r"C:\Users\AMAN\Dropbox\My PC (LAPTOP-K3QKQ8QO)\Downloads\forest2\forest dataset\forest dataset\trainset", target_size = (64,64),batch_size = 32,class_mode = "binary")
x_test = test_datagen.flow_from_directory(r"C:\Users\AMAN\Dropbox\My PC (LAPTOP-K3QKQ8QO)\Downloads\forest2\forest dataset\forest dataset\testset", target_size = (64,64),batch_size = 32,class_mode = "binary")
# Out:
# Found 216 images belonging to 2 classes.
# Found 137 images belonging to 2 classes.

# %%
model = Sequential()
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.add(Convolution2D(32,(3,3),input_shape = (64,64,3),activation = "relu"))
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
model.add(MaxPooling2D(pool_size = (2,2)))
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.add(Flatten())

# %%
model.add(Dense(units = 128,init = "random_uniform",activation = "relu"))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=128, activation="relu", kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
model.add(Dense(units = 64,init = "random_uniform",activation = "relu"))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=64, activation="relu", kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
model.add(Dense(units = 1,init = "random_uniform", activation = "sigmoid"))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=1, activation="sigmoid", kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
model.compile(optimizer = "adam", loss ="binary_crossentropy" , metrics = ["accuracy"] )
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
x_train.class_indices
# Out:
# {'forest with fire': 0, 'forest without fire': 1}

# %%
model.fit_generator(x_train, steps_per_epoch = 50,epochs =3,validation_data = x_test , validation_steps = 20,)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Epoch 1/3
# 50/50 [==============================] - 18s 358ms/step - loss: 0.3869 - acc: 0.8245 - val_loss: 0.3396 - val_acc: 0.8613
# Epoch 2/3
# 50/50 [==============================] - 16s 328ms/step - loss: 0.1428 - acc: 0.9482 - val_loss: 0.0552 - val_acc: 0.9854
# Epoch 3/3
# 50/50 [==============================] - 17s 332ms/step - loss: 0.1007 - acc: 0.9617 - val_loss: 0.0898 - val_acc: 0.9635

# %%
model.save("forest2_trial.h5")

# %%
import cv2
#import facevec
import numpy as np
import smtplib
from keras.preprocessing import image 
from keras.models  import load_model

model = load_model('forest2_trial.h5') 
video = cv2.VideoCapture(0)
name = ['forest','with fire']
    
while(1):
    success, frame = video.read()
    cv2.imwrite("image.jpg",frame)
    img = image.load_img("image.jpg",target_size = (64,64))
    x  = image.img_to_array(img)
    x = np.expand_dims(x,axis = 0)
    pred = model.predict_classes(x)
    p = pred[0][0]
    print(pred)
    cv2.putText(frame, "predicted  class = "+str(name[p]), (100,100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,0), 1)
    
    
    pred = model.predict_classes(x)
    if pred[0][0]==1:
        gmail_user = 'forestofficial123'   #email id without @gmail.com
        gmail_password = 'forest!12'        #email passwrod
        #email properties
        sent_from = gmail_user
        to = ['babuamansingh@gmail.com']
        subject = 'Alert'
        email_text = """Alert for Fire Detection, stay alert"""
        server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
        server.ehlo()
        server.login(gmail_user, gmail_password)
        server.sendmail(sent_from, to, email_text)
        server.close()
        print('Fire Detected')
        print ('Email sent!')
        #break
    else:
        print("no danger")
       #break
    #cv2.putText(frame, "The animal is "+list(l.keys())[list(l.values()).index(p[0])], (200,200), cv2.FONT_HERSHEY_PLAIN, (1.5), (0,0,0), (1))
    cv2.imshow("image",frame)
   
    if cv2.waitKey(1) & 0xFF == ord('a'): 
        break

video.release()
cv2.destroyAllWindows()

# https://stackoverflow.com/questions/10147455/how-to-send-an-email-with-gmail-as-provider-using-python/27515833#27515833
#https://myaccount.google.com/lesssecureapps?pli=1&rapt=AEjHL4NdgTpfTko7aBB1CwmAw7k6a5sp2Uy5VY6j3sPWIZ4VUt2VPI6ercMhMXsP6bGog4rG-JzIaMOpY22AQtHneXsrOvPmRw
# Out:
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# ...
